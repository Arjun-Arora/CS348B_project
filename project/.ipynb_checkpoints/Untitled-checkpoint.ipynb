# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
map_x = np.loadtxt("normals_map_x.txt")
map_y = np.loadtxt("normals_map_y.txt")
map_final = np.dstack((map_x,map_y))

plt.imshow(map_final)
