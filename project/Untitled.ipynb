# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
map_x = np.loadtxt("normals_map_x.txt")
map_y = np.loadtxt("normals_map_y.txt")
depth_map = np.loadtxt("depth_map.txt")
depth_map = depth_map.T#/np.max(depth_map)
map_final =  np.dstack((map_x.T,map_y.T))
map_final_print = np.vstack((map_x.T,map_y.T,np.ones_like(map_x)))
plt.imshow(np.dstack((map_x.T,map_y.T,np.zeros_like(map_x.T))))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(depth_map, cmap='gray')
print(depth_map[0:5, 0:5])
print(depth_map[695:700, 695:700])
# Out:
# [[756.306 756.283 756.279 756.278 756.256]
#  [756.542 756.537 756.53  756.501 756.501]
#  [756.786 756.764 756.745 756.761 756.725]
#  [757.034 757.002 757.002 756.974 756.982]
#  [757.251 757.264 757.225 757.225 757.2  ]]
# [[258.062 258.046 258.066 258.05  258.028]
#  [257.653 257.652 257.66  257.658 257.684]
#  [257.282 257.305 257.28  257.314 257.301]
#  [256.929 256.918 256.937 256.92  256.9  ]
#  [256.531 256.569 256.562 256.537 256.554]]

# %%
plt.imshow(map_y.T)
print(map_y[0:5,0:5])
# Out:
# [[-0.328598 -0.328598 -0.328598 -0.328598 -0.328598]
#  [-0.328598 -0.328598 -0.328598 -0.328598 -0.328598]
#  [-0.328598 -0.328598 -0.328598 -0.328598 -0.328598]
#  [-0.328598 -0.328598 -0.328598 -0.328598 -0.328598]
#  [-0.328598 -0.328598 -0.328598 -0.328598 -0.328598]]

# %%
plt.imshow(map_x.T)
print(map_x[0:5,0:5])
# Out:
# [[-0.019821 -0.019821 -0.019821 -0.019821 -0.019821]
#  [-0.019821 -0.019821 -0.019821 -0.019821 -0.019821]
#  [-0.019821 -0.019821 -0.019821 -0.019821 -0.019821]
#  [-0.019821 -0.019821 -0.019821 -0.019821 -0.019821]
#  [-0.019821 -0.019821 -0.019821 -0.019821 -0.019821]]
