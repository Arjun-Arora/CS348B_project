# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
map_x = np.loadtxt("normals_map_x.txt")
map_y = np.loadtxt("normals_map_y.txt")
depth_map = np.loadtxt("depth_map.txt")

depth_map = depth_map.T#/np.max(depth_map)
map_final =  np.dstack((map_x.T,map_y.T))
map_final_print = np.vstack((map_x.T,map_y.T,np.ones_like(map_x)))
plt.imshow(np.dstack((map_x.T,map_y.T,np.zeros_like(map_x.T))))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-24d04dacf91c> in <module>()
#       2 map_y = np.loadtxt("normals_map_y.txt")
#       3 depth_map = np.loadtxt("depth_map.txt")
# ----> 4 albedo_map = np.loadtxt('albedo.txt')
#       5 depth_map = depth_map.T#/np.max(depth_map)
#       6 map_final =  np.dstack((map_x.T,map_y.T))
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#    1099         # converting the data
#    1100         X = None
# -> 1101         for x in read_data(_loadtxt_chunksize):
#    1102             if X is None:
#    1103                 X = np.array(x, dtype)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1026
#    1027             # Convert each value according to its column and store
# -> 1028             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1029
#    1030             # Then pack it according to the dtype's nesting
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in <listcomp>(.0)
#    1026
#    1027             # Convert each value according to its column and store
# -> 1028             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1029
#    1030             # Then pack it according to the dtype's nesting
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in floatconv(x)
#     744         if '0x' in x:
#     745             return float.fromhex(x)
# --> 746         return float(x)
#     747
#     748     typ = dtype.type
#
# ValueError: could not convert string to float: '['

# %%
plt.imshow(map_x.T)
print(map_y[0:5,0:5])
# Out:
# [[-0.328598 -0.328598 -0.328598 -0.328598 -0.328598]
#  [-0.328598 -0.328598 -0.328598 -0.328598 -0.328598]
#  [-0.328598 -0.328598 -0.328598 -0.328598 -0.328598]
#  [-0.328598 -0.328598 -0.328598 -0.328598 -0.328598]
#  [-0.328598 -0.328598 -0.328598 -0.328598 -0.328598]]

# %%
plt.imshow(map_y.T)
print(map_x[0:5,0:5])
# Out:
# [[-0.019821 -0.019821 -0.019821 -0.019821 -0.019821]
#  [-0.019821 -0.019821 -0.019821 -0.019821 -0.019821]
#  [-0.019821 -0.019821 -0.019821 -0.019821 -0.019821]
#  [-0.019821 -0.019821 -0.019821 -0.019821 -0.019821]
#  [-0.019821 -0.019821 -0.019821 -0.019821 -0.019821]]

# %%
plt.imshow(depth_map)

# %%
#albedo_map = np.loadtxt('albedo.txt')
f = open('albedo.txt')
# print(f.read())
albedo_map = []
for line in f:
    triplets = line.split()
    albedo_map.append([[float(x) for x in triplet.split(',')] for triplet in triplets])
albedo_map = np.array(albedo_map)
albedo_map = np.transpose(albedo_map,(1,0,2))
print(albedo_map.shape)
plt.imshow(albedo_map)
# for i in range(0,len(triplets)):
#     triplets[i] = triplets[i].split(',')
# albedo_map = np.array(triplets,dtype=np.float)
# print(albedo_map.shape)
# print()
#         print(triplet.dtype)
#     print(item)
#     print(len(item))
# Out:
# (700, 700, 3)
